# %%
import pandas as pd

# %%
df0 = pd.read_csv('test_manifold_6d_0.csv')
df1 = pd.read_csv('test_manifold_6d_1.csv')

# %%
# Out:
#         br     tr         t         x         y         z            vx  \
# 0      0.0    0.0  0.000000  1.007543  0.000000  0.002674  1.000000e-10
# 1      0.0    0.0 -0.024517  1.007544 -0.000305  0.002668 -7.961943e-05
# 2      0.0    0.0 -0.100639  1.007560 -0.001239  0.002582 -3.425826e-04
# 3      0.0    0.0 -0.178199  1.007599 -0.002146  0.002393 -6.629306e-04
# 4      0.0    0.0 -0.266048  1.007676 -0.003080  0.002070 -1.110884e-03
# ...    ...    ...       ...       ...       ...       ...           ...
# 38562  0.0  308.0 -8.701079  1.000433  0.003866 -0.002717 -8.544345e-03
# 38563  0.0  308.0 -8.719419  1.000581  0.004208 -0.002832 -7.653284e-03
# 38564  0.0  308.0 -8.740396  1.000732  0.004567 -0.002935 -6.697497e-03
# 38565  0.0  308.0 -8.764399  1.000880  0.004941 -0.003023 -5.690619e-03
# 38566  0.0  308.0 -8.779245  1.000960  0.005153 -0.003063 -5.113480e-03
#
#              vy        vz
# 0      0.012448  0.000000
# 1      0.012424  0.000447
# ...

# %%
df0.to_csv('test_manifold_3d_0.csv', index=False, columns=['tr', 't', 'x', 'y', 'z'])
df1.to_csv('test_manifold_3d_1.csv', index=False, columns=['tr', 't', 'x', 'y', 'z'])
